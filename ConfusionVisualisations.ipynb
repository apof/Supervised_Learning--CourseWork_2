# %%
import numpy as np
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# %%
## polynomial 1 vs rest
confusion_array_error = np.array([np.array([0.0,0.02,0.35,0.24,0.12,0.69,0.65,0.0,0.67,0.30]),
                                  np.array([0.06,0.0,0.21,0.18,0.6,0.03,0.5,0.15,0.7,0.25]),
                                  np.array([0.16,0.05,0.0,0.56,0.79,0.47,0.25,0.66,0.70,0.15]),
                                  np.array([0.1,0.02,0.63,0.0,0.06,1.07,0.0,0.1,0.99,0.2]),
                                  np.array([0.09,0.23,0.38,0.06,0.0,0.69,0.36,0.64,0.6,1.25]),
                                  np.array([0.11,0.0,0.07,1.78,0.08,0.0,0.19,0.09,1.26,0.09]),
                                  np.array([0.35,0.16,0.14,0.0,0.38,0.99,0.0,0.0,0.46,0.0]),
                                  np.array([0.08,0.56,0.50,0.61,0.31,0.06,0.02,0.0,0.46,1.25]),
                                  np.array([0.1,0.04,0.21,1.18,0.14,0.4,0.27,0.32,0.0,0.17]),
                                  np.array([0.06,0.0,0.02,0.26,0.55,0.56,0.0,1.05,0.43,0.0])])

confusion_array_std = np.array([np.array([0.0,0.08,0.39,0.35,0.24,0.81,0.70,0.0,0.74,0.40]),
                                np.array([0.13,0.0,0.31,0.38,0.60,0.14,0.37,0.32,0.60,0.35]),
                                np.array([0.22,0.14,0.0,0.5,0.81,0.60,0.36,0.75,0.71,0.31]),
                                np.array([0.15,0.09,0.6,0.0,0.18,1.03,0.0,0.3,0.78,0.28]),
                                np.array([0.15,0.36,0.47,0.18,0.0,0.58,0.4,0.56,0.65,0.81]),
                                np.array([0.2,0.0,0.17,0.88,0.2,0.0,0.39,0.3,0.93,0.3]),
                                np.array([0.42,0.22,0.23,0.0,0.55,0.75,0.0,0.0,0.56,0.0]),
                                np.array([0.17,0.18,0.56,0.46,0.33,0.19,0.12,0.0,0.55,1.5]),
                                np.array([0.14,0.11,0.32,0.91,0.26,0.33,0.4,0.43,0.0,0.28]),
                                np.array([0.12,0.0,0.11,0.34,0.54,0.63,0.0,0.79,0.47,0.0])])

# %%
## polynomial 1 vs 1
confusion_array_error = np.array([[0.0,0.0,0.35,0.33,0.0,0.84,0.92,0.0,0.39,0.09],
                                  [0.0,0.0,0.19,0.07,0.84,0.0,0.57,0.015,0.29,0.20],
                                  [0.14,0.02,0.0,0.39,0.32,0.47,0.36,0.46,0.42,0.06],
                                  [0.11,0.0,0.15,0.0,0.06,1.23,0.0,0.06,1.46,0.06],
                                  [0.08,0.31,1.64,0.09,0.0,0.49,0.55,0.93,0.59,1.66],
                                  [0.34,0.0,0.05,2.62,0.15,0.0,0.36,1.12,1.53,0.09],
                                  [0.21,0.22,0.27,0.0,0.74,0.66,0.0,0.0,0.0,0.0],
                                  [0.02,0.02,0.81,0.24,0.38,0.07,0.0,0.0,0.37,2.25],
                                  [0.03,0.16,0.97,1.77,0.09,1.11,0.57,0.48,0.0,0.27],
                                  [0.05,0.02,0.08,0.21,2.28,0.62,0.03,2.12,0.21,0.0]])

confusion_array_std = np.array([[0.0,0.0,0.44,0.46,0.0,0.64,0.81,0.0,0.53,0.21],
                                [0.0,0.0,0.30,0.20,0.45,0.0,0.65,0.27,0.48,0.33],
                                [0.30,0.09,0.0,0.45,0.34,0.58,0.40,0.50,0.52,0.19],
                                [0.19,0.0,0.61,0.0,0.18,0.67,0.0,0.17,1.10,1.17],
                                [0.14,1.38,1.20,0.21,0.0,0.60,0.63,0.85,0.62,1.21],
                                [0.30,0.0,0.15,1.24,0.26,0.0,0.48,0.24,1.05,0.27],
                                [1.36,0.29,0.32,0.0,0.67,0.53,0.0,0.0,0.0,0.0],
                                [0.07,0.08,0.57,0.35,0.49,0.22,0.0,0.0,0.46,2.07],
                                [0.10,0.24,0.78,1.27,0.28,0.81,0.44,0.62,0.0,0.36],
                                [0.12,0.08,0.19,0.36,1.57,1.62,1.13,1.26,0.32,0.0]])

# %%
## gaussian 1 vs rest
confusion_array_error = np.array([[],
                                  [],
                                  [],
                                  [],
                                  [],
                                  [],
                                  [],
                                  [],
                                  [],
                                  []])
confusion_array_std = np.array([[],
                                [],
                                [],
                                [],
                                [],
                                [],
                                [],
                                [],
                                [],
                                []])

# %%
## adaboost 1 vs rest
confusion_array_error = np.array([[],
                                  [],
                                  [],
                                  [],
                                  [],
                                  [],
                                  [],
                                  [],
                                  [],
                                  []])

confusion_array_std = np.array([[],
                                [],
                                [],
                                [],
                                [],
                                [],
                                [],
                                [],
                                [],
                                []])

# %%
## svm 1 vs rest
confusion_array_error = np.array([[],
                                  [],
                                  [],
                                  [],
                                  [],
                                  [],
                                  [],
                                  [],
                                  [],
                                  []])

confusion_array_std = np.array([[],
                                [],
                                [],
                                [],
                                [],
                                [],
                                [],
                                [],
                                [],
                                []])

# %%
print(confusion_array_error.shape)
print(confusion_array_std.shape)
# Out:
# (10, 10)
# (10, 10)

# %%
arr = []
for row in confusion_array_std:
    print(len(row))
    for elem in row:
        arr.append(elem)
arr = np.array(arr)
arr = arr.reshape((10,10))

print("----")

arr = []
for row in confusion_array_error:
    print(len(row))
    for elem in row:
        arr.append(elem)
arr = np.array(arr)
arr = arr.reshape((10,10))
# Out:
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# ----
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10

# %%
df_cm = pd.DataFrame(confusion_array_error, index = [i for i in "0123456789"],
                  columns = [i for i in "0123456789"])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
df_cm = pd.DataFrame(confusion_array_std, index = [i for i in "0123456789"],
                  columns = [i for i in "0123456789"])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
# Out:
# <AxesSubplot:>
