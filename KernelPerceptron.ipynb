# %%
import utilities
import random
import pandas as pd
import numpy as np

# %%
random_data = random.sample(range(1, 100), 20)

# %%
random_labels = random.sample(range(1,90), 20)

# %%
random_data
# Out:
# [57, 69, 86, 67, 74, 83, 97, 7, 93, 32, 1, 72, 13, 84, 9, 82, 95, 25, 39, 89]

# %%
random_labels
# Out:
# [39, 21, 61, 65, 52, 22, 32, 80, 26, 68, 69, 33, 55, 83, 84, 43, 53, 4, 89, 75]

# %%
validation_indexes,training_indexes = utilities.cross_validation(8,20,9)

# %%
train_data,train_labels,valid_data,valid_labels = utilities.get_train_test_set(validation_indexes,training_indexes,random_data,random_labels)

# %%
print(train_data)
print(train_labels)
print(valid_data)
print(valid_labels)
# Out:
# [57 69 86 67 74 83 97  7 93 32  1 72 13 84  9 82 95 25]
# [39 21 61 65 52 22 32 80 26 68 69 33 55 83 84 43 53  4]
# [39 89]
# [89 75]

# %%
training_mini_file = 'Datasets/mini_train_set.csv'
testing_mini_file = 'Datasets/mini_test_set.csv'

# %%
## load the dataset into a pandas dataframe
train_data_frame = pd.read_csv(training_mini_file,sep = '  ') 
test_data_frame = pd.read_csv(testing_mini_file,sep = '  ')
# Out:
# /home/apostolos/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# /home/apostolos/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
train_data_frame.describe()
# Out:
#                3.         -1.       -1..1       -1..2       -1..3       -1..4  \
# count  328.000000  328.000000  328.000000  328.000000  328.000000  328.000000
# mean     1.844512   -0.994436   -0.977466   -0.939247   -0.866326   -0.732027
# std      0.744131    0.072894    0.157612    0.280705    0.414468    0.553796
# min      1.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 25%      1.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 50%      2.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 75%      2.000000   -1.000000   -1.000000   -1.000000   -1.000000   -0.915500
# max      3.000000    0.166000    0.861000    1.000000    1.000000    1.000000
#
#            -0.928      -0.204       0.751       0.466  ...     0.466.1  \
# count  328.000000  328.000000  328.000000  328.000000  ...  328.000000
# mean    -0.568043   -0.328104    0.153137   -0.067912  ...   -0.476360
# ...

# %%
test_data_frame.describe()
# Out:
#                3.  Unnamed: 1  Unnamed: 2         -1.  Unnamed: 4  Unnamed: 5  \
# count  455.000000         0.0         0.0  455.000000         0.0         0.0
# mean     1.901099         NaN         NaN   -0.995527         NaN         NaN
# std      0.819032         NaN         NaN    0.050413         NaN         NaN
# min      1.000000         NaN         NaN   -1.000000         NaN         NaN
# 25%      1.000000         NaN         NaN   -1.000000         NaN         NaN
# 50%      2.000000         NaN         NaN   -1.000000         NaN         NaN
# 75%      3.000000         NaN         NaN   -1.000000         NaN         NaN
# max      3.000000         NaN         NaN   -0.235000         NaN         NaN
#
#             -1..1  Unnamed: 7  Unnamed: 8       -1..2  ...     -1..124  \
# count  455.000000         0.0         0.0  455.000000  ...  455.000000
# mean    -0.973745         NaN         NaN   -0.936389  ...   -0.885585
# ...

# %%
# convert dataframe to np array
train_data = train_data_frame.to_numpy()
print(train_data.shape)
test_data = test_data_frame.to_numpy()
print(test_data.shape)
# Out:
# (328, 769)
# (455, 769)
